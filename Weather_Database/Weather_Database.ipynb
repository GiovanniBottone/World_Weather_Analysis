# %%
# Deliverable 1

# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 765

# %%
#Perform an API call with OpenWeatherMap 
#Import dependencies
import requests
from config import Weather_API_Key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + Weather_API_Key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ca mau
# Processing Record 2 of Set 1 | along
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 1 | chuy
# Processing Record 7 of Set 1 | chifeng
# Processing Record 8 of Set 1 | yar-sale
# Processing Record 9 of Set 1 | carauari
# Processing Record 10 of Set 1 | sumbe
# Processing Record 11 of Set 1 | la ronge
# Processing Record 12 of Set 1 | soe
# Processing Record 13 of Set 1 | hamilton
# Processing Record 14 of Set 1 | tasiilaq
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | bereda
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | portland
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | skibbereen
# Processing Record 26 of Set 1 | pangnirtung
# Processing Record 27 of Set 1 | zhongshu
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | eldorado
# Processing Record 30 of Set 1 | esperance
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | lincoln
# Processing Record 34 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | alofi
# Processing Record 37 of Set 1 | urulga
# City not found. Skipping...
# Processing Record 38 of Set 1 | morehead
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | marzuq
# Processing Record 42 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | poso
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | dese
# Processing Record 48 of Set 1 | mandalgovi
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | hervey bay
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | nanortalik
# Processing Record 4 of Set 2 | kaniama
# Processing Record 5 of Set 2 | vila franca do campo
# Processing Record 6 of Set 2 | tahara
# Processing Record 7 of Set 2 | phangnga
# Processing Record 8 of Set 2 | kungurtug
# Processing Record 9 of Set 2 | muros
# Processing Record 10 of Set 2 | port-gentil
# Processing Record 11 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 2 | college
# Processing Record 13 of Set 2 | ambilobe
# Processing Record 14 of Set 2 | victoria
# Processing Record 15 of Set 2 | maneadero
# Processing Record 16 of Set 2 | todos santos
# Processing Record 17 of Set 2 | mount isa
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | usinsk
# Processing Record 20 of Set 2 | kargasok
# Processing Record 21 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | qujing
# Processing Record 24 of Set 2 | litovko
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | ginda
# Processing Record 27 of Set 2 | iskateley
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | cabedelo
# Processing Record 30 of Set 2 | christchurch
# Processing Record 31 of Set 2 | sabzevar
# Processing Record 32 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | fujisawa
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | senanga
# Processing Record 37 of Set 2 | eyl
# Processing Record 38 of Set 2 | voznesenye
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | cururupu
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | mineiros
# Processing Record 43 of Set 2 | kaitangata
# Processing Record 44 of Set 2 | souillac
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | kieta
# Processing Record 47 of Set 2 | bubaque
# Processing Record 48 of Set 2 | leningradskiy
# Processing Record 49 of Set 2 | kalmunai
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 1 of Set 3 | deputatskiy
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 3 | cockburn town
# Processing Record 5 of Set 3 | sola
# Processing Record 6 of Set 3 | haines junction
# Processing Record 7 of Set 3 | naze
# Processing Record 8 of Set 3 | champerico
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 3 | vao
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | yarada
# Processing Record 15 of Set 3 | torbay
# Processing Record 16 of Set 3 | fuling
# Processing Record 17 of Set 3 | marsa matruh
# Processing Record 18 of Set 3 | progreso
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | khatanga
# Processing Record 23 of Set 3 | puerto ayora
# Processing Record 24 of Set 3 | bela
# Processing Record 25 of Set 3 | airai
# Processing Record 26 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 3 | elizabeth city
# Processing Record 28 of Set 3 | pital
# Processing Record 29 of Set 3 | mareeba
# Processing Record 30 of Set 3 | gejiu
# Processing Record 31 of Set 3 | tuatapere
# Processing Record 32 of Set 3 | vaini
# Processing Record 33 of Set 3 | yellowknife
# Processing Record 34 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 3 | belle fourche
# Processing Record 36 of Set 3 | hobyo
# Processing Record 37 of Set 3 | henties bay
# Processing Record 38 of Set 3 | karratha
# Processing Record 39 of Set 3 | post falls
# Processing Record 40 of Set 3 | constitucion
# Processing Record 41 of Set 3 | auki
# Processing Record 42 of Set 3 | ronne
# Processing Record 43 of Set 3 | francistown
# Processing Record 44 of Set 3 | mvuma
# Processing Record 45 of Set 3 | kondopoga
# Processing Record 46 of Set 3 | prainha
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | bredasdorp
# Processing Record 49 of Set 3 | luderitz
# Processing Record 50 of Set 3 | chara
# Processing Record 1 of Set 4 | georgetown
# Processing Record 2 of Set 4 | butaritari
# Processing Record 3 of Set 4 | vrangel
# Processing Record 4 of Set 4 | sitka
# Processing Record 5 of Set 4 | northam
# Processing Record 6 of Set 4 | namatanai
# Processing Record 7 of Set 4 | eenhana
# Processing Record 8 of Set 4 | hithadhoo
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | chakulia
# Processing Record 11 of Set 4 | ust-nera
# Processing Record 12 of Set 4 | kavieng
# Processing Record 13 of Set 4 | fukue
# Processing Record 14 of Set 4 | bilma
# Processing Record 15 of Set 4 | sioux lookout
# Processing Record 16 of Set 4 | vestmannaeyjar
# Processing Record 17 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 18 of Set 4 | matata
# Processing Record 19 of Set 4 | pisco
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | lalas
# Processing Record 22 of Set 4 | quatre cocos
# Processing Record 23 of Set 4 | dingle
# Processing Record 24 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 4 | port hardy
# Processing Record 26 of Set 4 | tessalit
# Processing Record 27 of Set 4 | altay
# Processing Record 28 of Set 4 | olafsvik
# Processing Record 29 of Set 4 | ridgecrest
# Processing Record 30 of Set 4 | cookeville
# Processing Record 31 of Set 4 | bon accord
# Processing Record 32 of Set 4 | laguna
# Processing Record 33 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 4 | sao filipe
# Processing Record 36 of Set 4 | mount gambier
# Processing Record 37 of Set 4 | bredy
# Processing Record 38 of Set 4 | tigre
# Processing Record 39 of Set 4 | severo-kurilsk
# Processing Record 40 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 4 | talnakh
# Processing Record 42 of Set 4 | teruel
# Processing Record 43 of Set 4 | jiayuguan
# Processing Record 44 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | ketchikan
# Processing Record 46 of Set 4 | wanning
# Processing Record 47 of Set 4 | vanavara
# Processing Record 48 of Set 4 | los andes
# Processing Record 49 of Set 4 | ugoofaaru
# Processing Record 50 of Set 4 | sao felix do xingu
# Processing Record 1 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 2 of Set 5 | kirksville
# Processing Record 3 of Set 5 | sao joao da barra
# Processing Record 4 of Set 5 | korla
# Processing Record 5 of Set 5 | provideniya
# Processing Record 6 of Set 5 | udachnyy
# Processing Record 7 of Set 5 | boguchany
# Processing Record 8 of Set 5 | walvis bay
# Processing Record 9 of Set 5 | saint george
# Processing Record 10 of Set 5 | desoto
# Processing Record 11 of Set 5 | bengkulu
# Processing Record 12 of Set 5 | hailar
# Processing Record 13 of Set 5 | tevriz
# Processing Record 14 of Set 5 | el alto
# Processing Record 15 of Set 5 | berdigestyakh
# Processing Record 16 of Set 5 | puerto madryn
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | vagur
# Processing Record 19 of Set 5 | havre-saint-pierre
# Processing Record 20 of Set 5 | saldanha
# Processing Record 21 of Set 5 | rawlins
# Processing Record 22 of Set 5 | inirida
# Processing Record 23 of Set 5 | norman wells
# Processing Record 24 of Set 5 | codrington
# Processing Record 25 of Set 5 | roebourne
# Processing Record 26 of Set 5 | yulara
# Processing Record 27 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 5 | qaqortoq
# Processing Record 29 of Set 5 | ongandjera
# Processing Record 30 of Set 5 | port moresby
# Processing Record 31 of Set 5 | sangar
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | dryden
# Processing Record 34 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 5 | bay roberts
# Processing Record 36 of Set 5 | shitanjing
# Processing Record 37 of Set 5 | rongcheng
# Processing Record 38 of Set 5 | luau
# Processing Record 39 of Set 5 | cherskiy
# Processing Record 40 of Set 5 | pitelino
# Processing Record 41 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 5 | canakkale
# Processing Record 43 of Set 5 | horconcitos
# Processing Record 44 of Set 5 | deder
# Processing Record 45 of Set 5 | tursunzoda
# Processing Record 46 of Set 5 | luanshya
# Processing Record 47 of Set 5 | abha
# Processing Record 48 of Set 5 | luanda
# Processing Record 49 of Set 5 | upata
# Processing Record 50 of Set 5 | hami
# Processing Record 1 of Set 6 | grand gaube
# Processing Record 2 of Set 6 | chalmette
# Processing Record 3 of Set 6 | tilichiki
# Processing Record 4 of Set 6 | opuwo
# Processing Record 5 of Set 6 | carnarvon
# Processing Record 6 of Set 6 | andenes
# Processing Record 7 of Set 6 | aviles
# Processing Record 8 of Set 6 | veraval
# Processing Record 9 of Set 6 | mouzakion
# City not found. Skipping...
# Processing Record 10 of Set 6 | ibra
# Processing Record 11 of Set 6 | ixtapa
# Processing Record 12 of Set 6 | miyako
# Processing Record 13 of Set 6 | ahipara
# Processing Record 14 of Set 6 | rio grande
# Processing Record 15 of Set 6 | baykit
# Processing Record 16 of Set 6 | yanji
# Processing Record 17 of Set 6 | hofu
# Processing Record 18 of Set 6 | touros
# Processing Record 19 of Set 6 | maniitsoq
# Processing Record 20 of Set 6 | bealanana
# Processing Record 21 of Set 6 | klaksvik
# Processing Record 22 of Set 6 | port hedland
# Processing Record 23 of Set 6 | kozan
# Processing Record 24 of Set 6 | monrovia
# Processing Record 25 of Set 6 | tura
# Processing Record 26 of Set 6 | gagnoa
# Processing Record 27 of Set 6 | mersin
# Processing Record 28 of Set 6 | garm
# City not found. Skipping...
# Processing Record 29 of Set 6 | cabo san lucas
# Processing Record 30 of Set 6 | lata
# Processing Record 31 of Set 6 | wanlaweyn
# Processing Record 32 of Set 6 | sukumo
# Processing Record 33 of Set 6 | fortuna
# Processing Record 34 of Set 6 | surin
# Processing Record 35 of Set 6 | atambua
# Processing Record 36 of Set 6 | atar
# Processing Record 37 of Set 6 | pacific grove
# Processing Record 38 of Set 6 | flinders
# Processing Record 39 of Set 6 | danshui
# Processing Record 40 of Set 6 | makakilo city
# Processing Record 41 of Set 6 | srednekolymsk
# Processing Record 42 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 6 | jiexiu
# Processing Record 44 of Set 6 | pevek
# Processing Record 45 of Set 6 | inuvik
# Processing Record 46 of Set 6 | the valley
# Processing Record 47 of Set 6 | hinche
# Processing Record 48 of Set 6 | narsaq
# Processing Record 49 of Set 6 | sangueya
# Processing Record 50 of Set 6 | mattru
# Processing Record 1 of Set 7 | boa vista
# Processing Record 2 of Set 7 | hualmay
# Processing Record 3 of Set 7 | povazska bystrica
# Processing Record 4 of Set 7 | roald
# Processing Record 5 of Set 7 | leshukonskoye
# Processing Record 6 of Set 7 | araouane
# Processing Record 7 of Set 7 | lasa
# Processing Record 8 of Set 7 | dinhata
# Processing Record 9 of Set 7 | chenzhou
# Processing Record 10 of Set 7 | te anau
# Processing Record 11 of Set 7 | berlevag
# Processing Record 12 of Set 7 | urumqi
# Processing Record 13 of Set 7 | broken hill
# Processing Record 14 of Set 7 | saravena
# Processing Record 15 of Set 7 | horodyshche
# Processing Record 16 of Set 7 | winnemucca
# Processing Record 17 of Set 7 | aksarka
# Processing Record 18 of Set 7 | kaoma
# Processing Record 19 of Set 7 | dunkirk
# Processing Record 20 of Set 7 | karwar
# Processing Record 21 of Set 7 | seymchan
# Processing Record 22 of Set 7 | snezhnogorsk
# Processing Record 23 of Set 7 | gardez
# Processing Record 24 of Set 7 | barcelos
# Processing Record 25 of Set 7 | steamboat springs
# Processing Record 26 of Set 7 | sechelt
# Processing Record 27 of Set 7 | palm valley
# Processing Record 28 of Set 7 | baker city
# Processing Record 29 of Set 7 | irricana
# Processing Record 30 of Set 7 | morondava
# Processing Record 31 of Set 7 | clarence town
# Processing Record 32 of Set 7 | mana
# Processing Record 33 of Set 7 | taoudenni
# Processing Record 34 of Set 7 | hammerfest
# Processing Record 35 of Set 7 | banda aceh
# Processing Record 36 of Set 7 | vigrestad
# Processing Record 37 of Set 7 | bom jardim
# Processing Record 38 of Set 7 | lifford
# Processing Record 39 of Set 7 | at-bashi
# Processing Record 40 of Set 7 | boende
# Processing Record 41 of Set 7 | kinna
# Processing Record 42 of Set 7 | temiscaming
# Processing Record 43 of Set 7 | dongsheng
# Processing Record 44 of Set 7 | mehamn
# Processing Record 45 of Set 7 | bahia blanca
# Processing Record 46 of Set 7 | fort nelson
# Processing Record 47 of Set 7 | goure
# Processing Record 48 of Set 7 | porto murtinho
# Processing Record 49 of Set 7 | langsa
# Processing Record 50 of Set 7 | loreto
# Processing Record 1 of Set 8 | moree
# Processing Record 2 of Set 8 | tiarei
# Processing Record 3 of Set 8 | nuevo progreso
# Processing Record 4 of Set 8 | powell river
# Processing Record 5 of Set 8 | husavik
# Processing Record 6 of Set 8 | itarema
# Processing Record 7 of Set 8 | maputo
# Processing Record 8 of Set 8 | okhotsk
# Processing Record 9 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 10 of Set 8 | barra patuca
# Processing Record 11 of Set 8 | necochea
# Processing Record 12 of Set 8 | agutaya
# Processing Record 13 of Set 8 | loudi
# Processing Record 14 of Set 8 | aloleng
# Processing Record 15 of Set 8 | ransang
# Processing Record 16 of Set 8 | asau
# Processing Record 17 of Set 8 | albacete
# Processing Record 18 of Set 8 | batticaloa
# Processing Record 19 of Set 8 | comodoro rivadavia
# Processing Record 20 of Set 8 | pascagoula
# Processing Record 21 of Set 8 | kawalu
# Processing Record 22 of Set 8 | anthia
# City not found. Skipping...
# Processing Record 23 of Set 8 | mananara
# Processing Record 24 of Set 8 | tarakan
# Processing Record 25 of Set 8 | maumere
# Processing Record 26 of Set 8 | kulhudhuffushi
# Processing Record 27 of Set 8 | montrose
# Processing Record 28 of Set 8 | sayyan
# Processing Record 29 of Set 8 | datong
# Processing Record 30 of Set 8 | gat
# Processing Record 31 of Set 8 | port shepstone
# Processing Record 32 of Set 8 | graaff-reinet
# Processing Record 33 of Set 8 | kashi
# Processing Record 34 of Set 8 | san vicente
# Processing Record 35 of Set 8 | cao bang
# Processing Record 36 of Set 8 | tabuk
# Processing Record 37 of Set 8 | dera din panah
# City not found. Skipping...
# Processing Record 38 of Set 8 | mangrol
# Processing Record 39 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 40 of Set 8 | arlit
# Processing Record 41 of Set 8 | dhidhdhoo
# Processing Record 42 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 43 of Set 8 | ostrovnoy
# Processing Record 44 of Set 8 | lorengau
# Processing Record 45 of Set 8 | kruisfontein
# Processing Record 46 of Set 8 | cran-gevrier
# Processing Record 47 of Set 8 | vale da amoreira
# Processing Record 48 of Set 8 | zhigansk
# Processing Record 49 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 8 | brae
# Processing Record 1 of Set 9 | chicama
# Processing Record 2 of Set 9 | porto novo
# Processing Record 3 of Set 9 | omsukchan
# Processing Record 4 of Set 9 | ilulissat
# Processing Record 5 of Set 9 | paramonga
# Processing Record 6 of Set 9 | katsuura
# Processing Record 7 of Set 9 | rieti
# Processing Record 8 of Set 9 | karcag
# Processing Record 9 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 9 | san cristobal
# Processing Record 11 of Set 9 | taybad
# Processing Record 12 of Set 9 | alice springs
# Processing Record 13 of Set 9 | mahajanga
# Processing Record 14 of Set 9 | east london
# Processing Record 15 of Set 9 | thinadhoo
# Processing Record 16 of Set 9 | kailua
# Processing Record 17 of Set 9 | tutoia
# Processing Record 18 of Set 9 | nouakchott
# Processing Record 19 of Set 9 | clyde river
# Processing Record 20 of Set 9 | ouadda
# Processing Record 21 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 22 of Set 9 | kyshtovka
# Processing Record 23 of Set 9 | beringovskiy
# Processing Record 24 of Set 9 | oranjemund
# Processing Record 25 of Set 9 | kahului
# Processing Record 26 of Set 9 | ilebo
# Processing Record 27 of Set 9 | awbari
# Processing Record 28 of Set 9 | trapani
# Processing Record 29 of Set 9 | tautira
# Processing Record 30 of Set 9 | bathsheba
# Processing Record 31 of Set 9 | waingapu
# Processing Record 32 of Set 9 | lazi
# Processing Record 33 of Set 9 | longyearbyen
# Processing Record 34 of Set 9 | maicao
# Processing Record 35 of Set 9 | dikson
# Processing Record 36 of Set 9 | port-cartier
# Processing Record 37 of Set 9 | raton
# Processing Record 38 of Set 9 | hovd
# Processing Record 39 of Set 9 | ocean city
# Processing Record 40 of Set 9 | pacifica
# Processing Record 41 of Set 9 | casambalangan
# Processing Record 42 of Set 9 | guymon
# Processing Record 43 of Set 9 | san quintin
# Processing Record 44 of Set 9 | tukrah
# Processing Record 45 of Set 9 | maksatikha
# Processing Record 46 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 9 | kamaishi
# Processing Record 48 of Set 9 | belmonte
# Processing Record 49 of Set 9 | kaeo
# Processing Record 50 of Set 9 | carballo
# Processing Record 1 of Set 10 | oussouye
# Processing Record 2 of Set 10 | manokwari
# Processing Record 3 of Set 10 | homer
# Processing Record 4 of Set 10 | dahegam
# Processing Record 5 of Set 10 | goderich
# Processing Record 6 of Set 10 | vardo
# Processing Record 7 of Set 10 | tricase
# Processing Record 8 of Set 10 | anadyr
# Processing Record 9 of Set 10 | nador
# Processing Record 10 of Set 10 | rognan
# Processing Record 11 of Set 10 | kadaya
# Processing Record 12 of Set 10 | taguatinga
# Processing Record 13 of Set 10 | marawi
# Processing Record 14 of Set 10 | samarai
# Processing Record 15 of Set 10 | tual
# Processing Record 16 of Set 10 | harper
# Processing Record 17 of Set 10 | tucuman
# Processing Record 18 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 10 | mardin
# Processing Record 20 of Set 10 | mananjary
# Processing Record 21 of Set 10 | andijon
# Processing Record 22 of Set 10 | bloemfontein
# Processing Record 23 of Set 10 | linkoping
# Processing Record 24 of Set 10 | troutdale
# Processing Record 25 of Set 10 | chippewa falls
# Processing Record 26 of Set 10 | kendari
# Processing Record 27 of Set 10 | dillingen
# Processing Record 28 of Set 10 | bambous virieux
# Processing Record 29 of Set 10 | lavrentiya
# Processing Record 30 of Set 10 | unai
# Processing Record 31 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 10 | tecoanapa
# Processing Record 33 of Set 10 | salalah
# Processing Record 34 of Set 10 | praia
# Processing Record 35 of Set 10 | mumford
# Processing Record 36 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 37 of Set 10 | shingu
# Processing Record 38 of Set 10 | surt
# Processing Record 39 of Set 10 | luohe
# Processing Record 40 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 41 of Set 10 | marathon
# Processing Record 42 of Set 10 | arrecife
# Processing Record 43 of Set 10 | santa cruz de tenerife
# Processing Record 44 of Set 10 | severnoye
# Processing Record 45 of Set 10 | ilheus
# Processing Record 46 of Set 10 | tafresh
# Processing Record 47 of Set 10 | broome
# Processing Record 48 of Set 10 | vostok
# Processing Record 49 of Set 10 | ulladulla
# Processing Record 50 of Set 10 | san patricio
# Processing Record 1 of Set 11 | les ponts-de-ce
# Processing Record 2 of Set 11 | dunedin
# Processing Record 3 of Set 11 | ahuimanu
# Processing Record 4 of Set 11 | krapina
# Processing Record 5 of Set 11 | ancud
# Processing Record 6 of Set 11 | newport
# Processing Record 7 of Set 11 | lompoc
# Processing Record 8 of Set 11 | tochio
# Processing Record 9 of Set 11 | asfi
# Processing Record 10 of Set 11 | cape coast
# Processing Record 11 of Set 11 | padang
# Processing Record 12 of Set 11 | margate
# Processing Record 13 of Set 11 | santa barbara
# Processing Record 14 of Set 11 | azangaro
# Processing Record 15 of Set 11 | dhangadhi
# Processing Record 16 of Set 11 | katangli
# Processing Record 17 of Set 11 | palana
# Processing Record 18 of Set 11 | rio gallegos
# Processing Record 19 of Set 11 | coihaique
# Processing Record 20 of Set 11 | springfield
# Processing Record 21 of Set 11 | coquimbo
# Processing Record 22 of Set 11 | makat
# Processing Record 23 of Set 11 | ukiah
# Processing Record 24 of Set 11 | los llanos de aridane
# Processing Record 25 of Set 11 | bitung
# Processing Record 26 of Set 11 | kalemie
# Processing Record 27 of Set 11 | svetlogorsk
# Processing Record 28 of Set 11 | trairi
# Processing Record 29 of Set 11 | madisonville
# Processing Record 30 of Set 11 | dabat
# Processing Record 31 of Set 11 | keti bandar
# Processing Record 32 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 11 | oksfjord
# Processing Record 34 of Set 11 | hamura
# Processing Record 35 of Set 11 | sarkand
# Processing Record 36 of Set 11 | saint-augustin
# Processing Record 37 of Set 11 | jalu
# Processing Record 38 of Set 11 | pontianak
# Processing Record 39 of Set 11 | komsomolskiy
# Processing Record 40 of Set 11 | houston
# Processing Record 41 of Set 11 | sedlcany
# Processing Record 42 of Set 11 | cazones
# Processing Record 43 of Set 11 | velsk
# Processing Record 44 of Set 11 | kupang
# Processing Record 45 of Set 11 | pangai
# Processing Record 46 of Set 11 | namibe
# Processing Record 47 of Set 11 | egvekinot
# Processing Record 48 of Set 11 | karamakhi
# Processing Record 49 of Set 11 | richards bay
# Processing Record 50 of Set 11 | lewistown
# Processing Record 1 of Set 12 | astoria
# Processing Record 2 of Set 12 | noyabrsk
# Processing Record 3 of Set 12 | irece
# Processing Record 4 of Set 12 | moindou
# Processing Record 5 of Set 12 | victor harbor
# Processing Record 6 of Set 12 | skovorodino
# Processing Record 7 of Set 12 | jaen
# Processing Record 8 of Set 12 | grindavik
# Processing Record 9 of Set 12 | gigmoto
# Processing Record 10 of Set 12 | dauphin
# Processing Record 11 of Set 12 | poshekhonye
# Processing Record 12 of Set 12 | balaipungut
# Processing Record 13 of Set 12 | aykhal
# Processing Record 14 of Set 12 | ulaangom
# Processing Record 15 of Set 12 | kannangad
# Processing Record 16 of Set 12 | shache
# Processing Record 17 of Set 12 | zasechnoye
# Processing Record 18 of Set 12 | umea
# Processing Record 19 of Set 12 | doctor juan leon mallorquin
# Processing Record 20 of Set 12 | bartica
# Processing Record 21 of Set 12 | cap-haitien
# Processing Record 22 of Set 12 | morden
# Processing Record 23 of Set 12 | kununurra
# Processing Record 24 of Set 12 | tiksi
# Processing Record 25 of Set 12 | huarmey
# Processing Record 26 of Set 12 | matara
# Processing Record 27 of Set 12 | yanam
# Processing Record 28 of Set 12 | flagstaff
# Processing Record 29 of Set 12 | meulaboh
# Processing Record 30 of Set 12 | shimoda
# Processing Record 31 of Set 12 | westport
# Processing Record 32 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 12 | ornskoldsvik
# Processing Record 34 of Set 12 | kirakira
# Processing Record 35 of Set 12 | mecca
# Processing Record 36 of Set 12 | goundam
# Processing Record 37 of Set 12 | colares
# Processing Record 38 of Set 12 | mitu
# Processing Record 39 of Set 12 | vestmanna
# Processing Record 40 of Set 12 | merauke
# Processing Record 41 of Set 12 | mudkhed
# Processing Record 42 of Set 12 | greeley
# Processing Record 43 of Set 12 | tumbi
# Processing Record 44 of Set 12 | thunder bay
# Processing Record 45 of Set 12 | concepcion del oro
# Processing Record 46 of Set 12 | yeppoon
# Processing Record 47 of Set 12 | faya
# Processing Record 48 of Set 12 | sortland
# Processing Record 49 of Set 12 | uzhur
# Processing Record 50 of Set 12 | guerrero negro
# Processing Record 1 of Set 13 | marginea
# Processing Record 2 of Set 13 | fenoarivo
# Processing Record 3 of Set 13 | enshi
# Processing Record 4 of Set 13 | chor
# Processing Record 5 of Set 13 | sheridan
# Processing Record 6 of Set 13 | hofn
# Processing Record 7 of Set 13 | cayenne
# Processing Record 8 of Set 13 | visnes
# Processing Record 9 of Set 13 | whitianga
# Processing Record 10 of Set 13 | port lincoln
# Processing Record 11 of Set 13 | sabanalarga
# Processing Record 12 of Set 13 | byron bay
# Processing Record 13 of Set 13 | san jose
# Processing Record 14 of Set 13 | malartic
# Processing Record 15 of Set 13 | pacasmayo
# Processing Record 16 of Set 13 | talaya
# Processing Record 17 of Set 13 | fare
# Processing Record 18 of Set 13 | kloulklubed
# Processing Record 19 of Set 13 | katiola
# Processing Record 20 of Set 13 | peoria
# Processing Record 21 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 22 of Set 13 | falam
# Processing Record 23 of Set 13 | andros town
# Processing Record 24 of Set 13 | saravan
# Processing Record 25 of Set 13 | oparino
# Processing Record 26 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 13 | paita
# Processing Record 28 of Set 13 | cermik
# Processing Record 29 of Set 13 | dinguiraye
# Processing Record 30 of Set 13 | gardhiwala
# City not found. Skipping...
# Processing Record 31 of Set 13 | birjand
# Processing Record 32 of Set 13 | kidal
# Processing Record 33 of Set 13 | faqirwali
# Processing Record 34 of Set 13 | lagoa
# Processing Record 35 of Set 13 | sacramento
# Processing Record 36 of Set 13 | ust-maya
# Processing Record 37 of Set 13 | onega
# Processing Record 38 of Set 13 | buraydah
# Processing Record 39 of Set 13 | saint-louis
# Processing Record 40 of Set 13 | formosa
# Processing Record 41 of Set 13 | alghero
# Processing Record 42 of Set 13 | coromandel
# Processing Record 43 of Set 13 | kudahuvadhoo
# Processing Record 44 of Set 13 | san policarpo
# Processing Record 45 of Set 13 | pozhva
# Processing Record 46 of Set 13 | saint anthony
# Processing Record 47 of Set 13 | nosy varika
# Processing Record 48 of Set 13 | wukari
# Processing Record 49 of Set 13 | pedasi
# Processing Record 50 of Set 13 | maraa
# Processing Record 1 of Set 14 | vila
# Processing Record 2 of Set 14 | luwuk
# Processing Record 3 of Set 14 | novorzhev
# Processing Record 4 of Set 14 | lavumisa
# Processing Record 5 of Set 14 | teguldet
# Processing Record 6 of Set 14 | kalmar
# Processing Record 7 of Set 14 | kenai
# Processing Record 8 of Set 14 | aljezur
# Processing Record 9 of Set 14 | grimari
# City not found. Skipping...
# Processing Record 10 of Set 14 | buckie
# Processing Record 11 of Set 14 | port blair
# Processing Record 12 of Set 14 | liuhe
# Processing Record 13 of Set 14 | belaya gora
# Processing Record 14 of Set 14 | rundu
# Processing Record 15 of Set 14 | kozhva
# Processing Record 16 of Set 14 | calama
# Processing Record 17 of Set 14 | pangoa
# Processing Record 18 of Set 14 | antalaha
# Processing Record 19 of Set 14 | torbat-e jam
# Processing Record 20 of Set 14 | dali
# Processing Record 21 of Set 14 | sakyla
# Processing Record 22 of Set 14 | ningan
# City not found. Skipping...
# Processing Record 23 of Set 14 | rambouillet
# Processing Record 24 of Set 14 | bogorodsk
# Processing Record 25 of Set 14 | kysyl-syr
# Processing Record 26 of Set 14 | tadine
# Processing Record 27 of Set 14 | itupiranga
# Processing Record 28 of Set 14 | skjervoy
# Processing Record 29 of Set 14 | atagay
# Processing Record 30 of Set 14 | grande prairie
# Processing Record 31 of Set 14 | khalkhal
# Processing Record 32 of Set 14 | longonjo
# Processing Record 33 of Set 14 | chamrajnagar
# Processing Record 34 of Set 14 | mabaruma
# Processing Record 35 of Set 14 | palu
# Processing Record 36 of Set 14 | chadiza
# Processing Record 37 of Set 14 | charters towers
# Processing Record 38 of Set 14 | marsh harbour
# Processing Record 39 of Set 14 | kaduy
# Processing Record 40 of Set 14 | plugari
# Processing Record 41 of Set 14 | amahai
# Processing Record 42 of Set 14 | kasama
# Processing Record 43 of Set 14 | cap malheureux
# Processing Record 44 of Set 14 | tsiroanomandidy
# Processing Record 45 of Set 14 | nizhniy kuranakh
# Processing Record 46 of Set 14 | athabasca
# Processing Record 47 of Set 14 | cozumel
# Processing Record 48 of Set 14 | palmerston
# Processing Record 49 of Set 14 | pishin
# Processing Record 50 of Set 14 | tigil
# Processing Record 1 of Set 15 | tondano
# Processing Record 2 of Set 15 | guanica
# Processing Record 3 of Set 15 | gamba
# Processing Record 4 of Set 15 | meadville
# Processing Record 5 of Set 15 | pasni
# Processing Record 6 of Set 15 | pochutla
# Processing Record 7 of Set 15 | aklera
# Processing Record 8 of Set 15 | mkuranga
# Processing Record 9 of Set 15 | acapulco
# Processing Record 10 of Set 15 | bilibino
# Processing Record 11 of Set 15 | birao
# Processing Record 12 of Set 15 | sistranda
# Processing Record 13 of Set 15 | saint-ambroise
# Processing Record 14 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 15 | excelsior springs
# Processing Record 17 of Set 15 | daru
# Processing Record 18 of Set 15 | yerbogachen
# Processing Record 19 of Set 15 | iztapa
# Processing Record 20 of Set 15 | zhuhai
# Processing Record 21 of Set 15 | kunya
# Processing Record 22 of Set 15 | sederot
# Processing Record 23 of Set 15 | sudak
# Processing Record 24 of Set 15 | sivagiri
# Processing Record 25 of Set 15 | aklavik
# Processing Record 26 of Set 15 | coachella
# Processing Record 27 of Set 15 | labuhan
# Processing Record 28 of Set 15 | bayir
# Processing Record 29 of Set 15 | valparaiso
# Processing Record 30 of Set 15 | maarianhamina
# Processing Record 31 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 32 of Set 15 | viransehir
# Processing Record 33 of Set 15 | polunochnoye
# Processing Record 34 of Set 15 | rawson
# Processing Record 35 of Set 15 | dicabisagan
# Processing Record 36 of Set 15 | hay river
# Processing Record 37 of Set 15 | trumbull
# Processing Record 38 of Set 15 | port augusta
# Processing Record 39 of Set 15 | buala
# Processing Record 40 of Set 15 | zeya
# Processing Record 41 of Set 15 | sinjar
# Processing Record 42 of Set 15 | beirut
# Processing Record 43 of Set 15 | deogarh
# Processing Record 44 of Set 15 | baglung
# Processing Record 45 of Set 15 | boshnyakovo
# Processing Record 46 of Set 15 | zonguldak
# Processing Record 47 of Set 15 | sur
# Processing Record 48 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 15 | magalia
# Processing Record 50 of Set 15 | san andres
# Processing Record 1 of Set 16 | linxia
# Processing Record 2 of Set 16 | lima
# Processing Record 3 of Set 16 | yeltsovka
# City not found. Skipping...
# Processing Record 4 of Set 16 | agadez
# Processing Record 5 of Set 16 | higuey
# City not found. Skipping...
# Processing Record 6 of Set 16 | darhan
# Processing Record 7 of Set 16 | chokwe
# Processing Record 8 of Set 16 | sao jose do egito
# Processing Record 9 of Set 16 | sofiysk
# City not found. Skipping...
# Processing Record 10 of Set 16 | laki
# Processing Record 11 of Set 16 | nogliki
# Processing Record 12 of Set 16 | yairipok
# Processing Record 13 of Set 16 | jaicos
# Processing Record 14 of Set 16 | flin flon
# Processing Record 15 of Set 16 | balangbalang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 712

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ca Mau      VN   9.1769  105.1500     88.47        50          35
# 1     Along      IN  28.1667   94.7667     59.45        60          35
# 2   Rikitea      PF -23.1203 -134.9692     78.08        74         100
# 3   Ushuaia      AR -54.8000  -68.3000     42.46        70          75
# 4      Chuy      UY -33.6971  -53.4616     72.16        94         100
# 5   Chifeng      CN  42.2683  118.9636     12.90        36           1
# 6  Yar-Sale      RU  66.8333   70.8333     -2.74        98          99
# 7  Carauari      BR  -4.8828  -66.8958     73.00        98          74
# 8     Sumbe      AO -11.2061   13.8437     73.63        82          94
# 9  La Ronge      CA  55.1001 -105.2842    -14.58        70           0
#
#    Wind Speed   Current Description
# 0       17.94      scattered clouds
# 1        1.68      scattered clouds
# 2       18.41       overcast clouds
# 3       18.41         broken clouds
# 4        7.54            light rain
# 5       15.70             clear sky
# 6        5.08       overcast clouds
# 7        1.86  heavy intensity rain
# 8        4.76       overcast clouds
# 9       10.36             clear sky

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
